# %%
import otoole
from otoole import visualise
from otoole import read
from otoole import preprocess
from otoole.preprocess import setup
from IPython.display import display, Image

# %%
yml = '../config/my_model_kenya.yaml'
data = '../data/Given_Data_0314.gmpl'
data_BAU = '../data/BAU_0320.gmpl'
data_excel = '../data/Given_Data_0314.xlsx'
data_PC = '../data/PC_0402.gmpl'

# %%
data,       defaults        = read(yml, 'datafile', data)
data_BAU,   defaults_BAU    = read(yml, 'datafile', data_BAU)
data_PC,    defaults_PC     = read(yml, 'datafile', data_PC)

# %%
visualise.create_res(data, '../pic/sys_diagram/ESR_ref.png')
display(Image('../pic/sys_diagram/ESR_ref.png'))

# %%
visualise.create_res(data_BAU, '../pic/sys_diagram/BAU_0320.png')
display(Image('../pic/sys_diagram/BAU_0320.png'))

# %%
visualise.create_res(data_PC, '../pic/sys_diagram/PC_0402.png')
display(Image('../pic/sys_diagram/PC_0402.png'))

# %%
# Convert MathProg data into Excel Data
otoole.convert('../config/my_model_essay.yaml', 'datafile', 'excel', '../data/BAU_0322_storage.gmpl', '../data/BAU_0322_storage.xlsx')
# Out:
# True

# %%
# Convert MathProg data into Excel Data
otoole.convert('../config/my_model_essay.yaml', 'excel', 'datafile', '../data/BAU_0322_storage.xlsx', '../data/BAU_0322_storage.gmpl')
# Out:
# True
